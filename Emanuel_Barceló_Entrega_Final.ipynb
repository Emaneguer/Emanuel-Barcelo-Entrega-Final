# %% [markdown]
# # Paso 1: Preparación OpenAI para Python

# %% [markdown]
# # Paso 2: Configurar la API

# %%
# Import openai
import openai
# openai api key
openai.api_key = "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"

# %% [markdown]
# # Paso 3: Crear la solicitud

# %% [markdown]
# Planteamos generar contenido atractivo y persuasivo aplicando conocimientos de marketing digital, para promocionar y vender cursos de dibujo online.

# %%
# Rol de System creación del contexto
context = "Eres un asistente experto en marketing digital y en dibujo realista"

# Rol de user
prompt = "Genera textos persuasivos que atraigan diversas audiencias que quieran aprender a dibujar, y comuniquen de manera efectiva los beneficios del curso que estoy promocionando y vendiendo"

# %% [markdown]
# # Paso 4: Configuración

# %%
# Creación de la conversación
conversation = [
    {"role": "system", "content": context },
    {"role": "user", "content": prompt },
]
# Solicitud para obtener la respuesta del modelo
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=conversation,
    max_tokens=500
)

message = response.choices[0]['message']
print("{}: {}".format(message['role'], message['content']))
# Out:
# assistant: ¡Aprende a dibujar como un profesional y libera tu creatividad con nuestro curso online! Descubre tu potencial artístico y perfecciona tus habilidades con la ayuda de nuestros expertos. Con clases prácticas y personalizadas, te enseñaremos las técnicas y fundamentos del dibujo realista para que puedas plasmar tus ideas de manera impactante y detallada. ¡No esperes más para convertirte en un artista completo! Inscríbete ahora y deja que tu imaginación vuele alto. ¡El arte está esperando por ti! 🎨✨ #AprendeADibujar #CreatividadSinLímites #CursoOnline

# %% [markdown]
# # Paso 5: Interpretación de la Respuesta

# %%
# Almacenar el resultado de la conversación
result = response['choices'][0]['message']['content'].strip()
# Manipular la respuesta
print("La respuesta es:", result)
# Out:
# La respuesta es: ¡Aprende a dibujar como un profesional y libera tu creatividad con nuestro curso online! Descubre tu potencial artístico y perfecciona tus habilidades con la ayuda de nuestros expertos. Con clases prácticas y personalizadas, te enseñaremos las técnicas y fundamentos del dibujo realista para que puedas plasmar tus ideas de manera impactante y detallada. ¡No esperes más para convertirte en un artista completo! Inscríbete ahora y deja que tu imaginación vuele alto. ¡El arte está esperando por ti! 🎨✨ #AprendeADibujar #CreatividadSinLímites #CursoOnline

# %% [markdown]
# # Paso 6: Reasignamos las variables para obtener una nueva respuesta
# One Shoot Prompting

# %%
# Rol de System creación del contexto
context = "Eres un asistente experto en marketing digital y en dibujo realista"

# Rol de asistente (chatGPT)
chatGPT_response = """1. Para principiantes: Descubre tu talento oculto y aprende a dibujar desde cero con nuestro curso especializado para principiantes. Con instrucciones paso a paso y ejercicios prácticos, en poco tiempo estarás creando tus propias obras maestras. ¡Es hora de dar rienda suelta a tu creatividad y sorprenderte a ti mismo con lo que eres capaz de lograr! 2. Para aficionados: Si ya tienes algo de experiencia en el mundo del dibujo y estás buscando llevar tus habilidades al siguiente nivel, este curso es para ti. Aprende técnicas avanzadas, perfecciona tu estilo y descubre cómo destacarte en un mercado cada vez más competitivo. ¡Potencia tu creatividad y conviértete en un verdadero maestro del dibujo! 3. Para amantes del arte:
Sumérgete en el maravilloso mundo del dibujo realista con nuestro curso especializado, diseñado para aquellos que buscan capturar la belleza y la esencia de la realidad en sus creaciones. Aprende a dominar sombras, luces y texturas, y convierte tus dibujos en verdaderas obras de arte que cautivarán a todos los que los contemplen. ¡Deja volar tu imaginación y déjate inspirar por la magia del arte!"
Recuerda siempre destacar los beneficios específicos de tu curso, como la calidad de los materiales, la experiencia del instructor, el acceso a una comunidad de aprendizaje, entre otros. ¡Buena suerte con la promoción de tu curso de dibujo!"""

# Rol de user
prompt = "Ahora necesito generar textos que tengan cuenta la siguiente frase motivadora: Cualquiera puede aprender a dibujar. No es un talento innato sino una habilidad que se puede adquirir con mucha práctica y paciencia."

# %%
# Creación de la conversación
conversation = [
    {"role": "system", "content": "Eres un asistente experto en marketing digital y en dibujo realista" },
    {"role": "user", "content": "Ahora necesito generar textos que tengan cuenta la siguiente frase motivadora: Cualquiera puede aprender a dibujar. No es un talento innato sino una habilidad que se puede adquirir con mucha práctica y paciencia"},
]
# Solicitud para obtener la respuesta del modelo
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=conversation,
    max_tokens=500
)

message = response.choices[0]['message']
print("{}: {}".format(message['role'], message['content']))
# Out:
# assistant: ¡Claro! Aquí te dejo algunas ideas de textos motivadores basados en la frase que has proporcionado:
#
# 1. "El dibujo no es un don exclusivo de unos pocos, es una destreza que se cultiva con esfuerzo y dedicación. ¡Tú también puedes aprender a dibujar!"
#
# 2. "La práctica constante y la paciencia son las claves para dominar el arte del dibujo. No importa tus habilidades iniciales, con determinación y tiempo, ¡tú también puedes lograrlo!"
#
# 3. "¿Crees que dibujar no es lo tuyo? Piénsalo de nuevo. La habilidad para plasmar tus ideas en papel se desarrolla con cada trazo. ¡Cualquiera puede aprender a dibujar, solo hace falta creer en ti mismo!"
#
# Espero que estos textos te resulten útiles. Si necesitas más ideas o alguna modificación, ¡estaré encantado de ayudarte!

# %% [markdown]
# # Paso 7: Introducimos una conversación con un posible comprador del curso
# Few Shoot Prompting

# %%
contexto_conversacion= """
Prospecto: Hola, quiero más información sobre Curso de Dibujo 2024
Vendedor: Hola! te has contactado con Curso de Dibujo 2024 ¿Cómo es tu nombre? 
Prospecto: Holaa que tal si me llamo Ivan Coronel
Prospecto: Mucho gusto  Ivan, soy Juan ¿Cómo estás?
Vendedor: Te gusta dibujar?
Prospecto: Si maestro bueno recién estoy empezando tengo 21 años soy muy principiante y me encantaría aprender este bello arte ojalá no sea muy tarde
Vendedor: Nunca es tarde. 
Vendedor: Cuanto tiempo llevas dibujando?
Prospecto: Aproximadamente unos 2 meses maestro ya le envío uno de mis dibujos me gustaría saber su opinión estado aprendiendo en YouTube
Vendedor:En base a esto voy a ofrecerte un programa que te ayudará a dominar el dibujo de la figura humana, el retrato, el bodegón, el paisaje y también el dibujo de animales. Las áreas mas importantes del dibujo.
Este curso cuenta con una modalidad completamente Online, y tienes la posibilidad de manejar sus tiempos ya que no tendrías horarios fijos para hacerlo.
Una vez que ingreses tienes acceso de por vida, e ingresarás a una comunidad exclusiva dónde puede consultar dudas y preguntar lo que sea necesario, en el proceso de aprendizaje. 
Prospecto: Me parece muy interesante el curso, pasa que pagar todo el curso ahora se me hace imposible, no dudo que el curso completo este buenisimo, pero por lo completo que es esta mas haya de lo que me puedo
perminitir en este momento, pero lo voy a tener presente si llega la oportunidad."""

# %% [markdown]
# # Paso 8: Creando solicitud
# Creando una solicitud a la API de OpenAI para one shoot prompting:
# Ahora haremos una prueba con few shoot prompting usando un contexto entre un posible prospecto (comprador del curso) y un vendedor

# %%
contexto_conversation = "Aquí va el contexto de la conversación."
pregunta_adicional="¿Cómo podría mejorar mi discurso para lograr generar mas atracción en los prospectos?"

# Combinamos el contexto de la conversación y la pregunta en un prompt
prompt = f"{contexto_conversation}\n\nP: {pregunta_adicional}\nR:"

response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    max_tokens=50,
    messages= [
        {"role": "system", "content": "Eres un asistente experto en marketing digital y en dibujo realista" },
        {"role": "user", "content": prompt},
])

message = response.choices[0] ['message']
print("{}:{}".format(message ['role'], message ['content']))
# Out:
# assistant:Una forma de mejorar tu discurso para generar más atracción en los prospectos es asegurarte de que sea claro, convincente y relevante para tu audiencia. Aquí hay algunas sugerencias:
#
# 1. Conoce a tu audiencia

# %% [markdown]
# # Paso 9: Implementar Pandas AI

# %% [markdown]
# Importar las librerías a usar

# %%
from pandasai import SmartDataframe
import pandas as pd
from pandasai.llm.openai import OpenAI
import warnings
warnings.filterwarnings('ignore')
from pandasai.smart_dataframe import SmartDataframe

# %% [markdown]
# # Usar la API Key

# %%
llm=OpenAI(api_token="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")

# %% [markdown]
# # Set variables de ambiente

# %%
csv_file = "interes.csv"

# Crear un Dataframe
# Especifica el delimitador al leer el archivo CSV
df_from_csv_file = pd.read_csv(csv_file, sep=',', encoding='latin-1')

# %%
df_from_csv_file
# Out:
#          Interes;Sexo Masculino;Sexo Femenino
# 0             Dibujo Realista de Paisajes;6;9
# 1            Dibujo Realista del Rostro;12;15
# 2   Dibujo Realista de la Figura Humana;15;13
# 3            Dibujo Realista de animales;6;15
# 4              Dibujo Realista de Bodegón;2;6
# 5                                          ;;
# 6                                          ;;
# 7                                          ;;
# 8                                          ;;
# 9                                          ;;
# 10                                         ;;
# 11                                         ;;
# 12                                         ;;

# %%
df_from_csv_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Edad     ; Sexo ;Interés en Dibujo Realista  20 non-null     object
# dtypes: object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# # Transformar el dataframe a un dataframe de AI

# %%
ai_df = SmartDataframe(df_from_csv_file, config={"llm": llm})

# %%
ai_df.chat("Mostrame el total de los masculinos Interesados en el dibujo realista")
# Out:
# 'Total de hombres interesados en dibujo realista: 2'

# %% [markdown]
# # Iteración sobre otros datos

# %%
ai_df.chat("Mostrame cuantas mujeres tienen interés en dibujo")
# Out:
# 4

# %%
print(ai_df.last_code_generated)
# Out:
# data = {'Edad     ; Sexo ;Interés en Dibujo Realista': ['61 años o más;Masculino;No', '10-17 años  ;Masculino;Sí', '61 años o más;Masculino;Sí']}
# df = dfs[0]
# female_interest_count = df['Edad     ; Sexo ;Interés en Dibujo Realista'].str.contains('Femenino;Sí').sum()
# result = {'type': 'number', 'value': female_interest_count}

# %%
ai_df.chat("Gráfico de tortas del interés total de estudiantes mujeres y hombres según el rango de edad y el sexo")
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 281, in run
#     output = (self.code_generation_pipeline | self.code_execution_pipeline).run(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 115, in execute
#     {"content_type": "response", "value": ResponseSerializer.serialize(result)},
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\responses\response_serializer.py", line 29, in serialize
#     with open(result["value"], "rb") as image_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Emanuel/CODER/coder-test/entrega_final/exports/charts/temp_chart.png'
# "Unfortunately, I was not able to answer your question, because of the following error:\n\n[Errno 2] No such file or directory: 'C:/Users/Emanuel/CODER/coder-test/entrega_final/exports/charts/temp_chart.png'\n"

# %%
ai_df.chat("Gráfico de barras del interés total según rango de edad y sexo")
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 64, in execute
#     result = code_manager.execute_code(code_to_run, code_context)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\helpers\code_manager.py", line 212, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 281, in run
#     output = (self.code_generation_pipeline | self.code_execution_pipeline).run(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 105, in execute
#     code_to_run = self._retry_run_code(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 139, in _retry_run_code
#     return self.on_retry(code, e)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 126, in on_code_retry
#     return self.code_exec_error_pipeline.run(correction_input)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\error_correction_pipeline\error_correction_pipeline.py", line 45, in run
#     return self.pipeline.run(input)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\code_generator.py", line 33, in execute
#     code = pipeline_context.config.llm.generate_code(input, pipeline_context)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\llm\base.py", line 196, in generate_code
#     response = self.call(instruction, context)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\llm\base.py", line 385, in call
#     self.chat_completion(self.last_prompt, memory)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\llm\base.py", line 359, in chat_completion
#     response = self.client.create(**params)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\openai\api_resources\chat_completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\openai\api_requestor.py", line 298, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\openai\api_requestor.py", line 700, in _interpret_response
#     self._interpret_response_line(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\openai\api_requestor.py", line 765, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for gpt-3.5-turbo in organization org-oHVpiAuAUQrZxvZFGjcAW570 on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nRate limit reached for gpt-3.5-turbo in organization org-oHVpiAuAUQrZxvZFGjcAW570 on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.\n'

# %% [markdown]
# # PandasAI desde PandasAI

# %%
import os
import pandas as pd
from pandasai import SmartDatalake
from pandasai.responses.streamlit_response import StreamlitResponse

# %%
df = pd.read_csv("interes.csv", encoding="latin-1")

os.environ["PANDASAI_API_KEY"] = "$2a$10$7d078oRAnVs3q.kXeH2ayeUTaaISWx.JrIOBpJ44rPug7YWACssem"

agent = SmartDatalake(
    [df],
    config={"verbose": True, "response_parser": StreamlitResponse},
)

# %%
agent.chat("Grafico de barras de la cantidad de interesados hombres y mujeres")
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 281, in run
#     output = (self.code_generation_pipeline | self.code_execution_pipeline).run(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 115, in execute
#     {"content_type": "response", "value": ResponseSerializer.serialize(result)},
#   File "C:\Users\Emanuel\miniconda3\envs\coder-test\lib\site-packages\pandasai\responses\response_serializer.py", line 29, in serialize
#     with open(result["value"], "rb") as image_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Emanuel/CODER/coder-test/entrega_final/exports/charts/temp_chart.png'
# "Unfortunately, I was not able to answer your question, because of the following error:\n\n[Errno 2] No such file or directory: 'C:/Users/Emanuel/CODER/coder-test/entrega_final/exports/charts/temp_chart.png'\n"

# %%
agent.chat("¿Dentro de estos masculinos cuantos son menores de 30 años?")
# Out:
# 1

# %% [markdown]
# # Gráfico de conocimiento

# %% [markdown]
# Importar Librerías

# %%
import openai
import matplotlib as plt
from io import StringIO
import csv

# %%
openai.api_key ="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"

# %%
# Datos de preferencias en las diferentes ramas del Dibujo Realista
data_str = """Cantidad de personas,Edades,Interes
75 personas,7 a 65 años,Dibujo de paisajes
96 personas,15 a 45 años,Dibujo del rostro
200 personas,10 a 35 años,Dibujo de la figura humana
80 personas,12 a 35 años,Dibujo de animales
20 personas,45 a 60 años,Dibujo de bodegón
"""

# Crear un objeto StringIO para simular un archivo CSV
csv_file = StringIO(data_str)

# Leer el CSV y almacenar los datos en una lista de diccionarios
reader = csv.DictReader(csv_file)
data = list(reader)

# Mostrar los datos
print(data)
# Out:
# [{'Cantidad de personas': '75 personas', 'Edades': '7 a 65 años', 'Interes': 'Dibujo de paisajes'}, {'Cantidad de personas': '96 personas', 'Edades': '15 a 45 años', 'Interes': 'Dibujo del rostro'}, {'Cantidad de personas': '200 personas', 'Edades': '10 a 35 años', 'Interes': 'Dibujo de la figura humana'}, {'Cantidad de personas': '80 personas', 'Edades': '12 a 35 años', 'Interes': 'Dibujo de animales'}, {'Cantidad de personas': '20 personas', 'Edades': '45 a 60 años', 'Interes': 'Dibujo de bodegón'}]

# %%
prompt = "Quiero que tomando en cuenta los datos del contexto extraigas entidades y relaciones entre los datos con el objetivo de crear un gráfico {'Cantidad': '75 personas', 'Rango etario': '7 a 65 años', 'Interes': 'Dibujo de paisajes'}, {'Cantidad': '96 personas', 'Rango etario': '10 a 35 años' 'Interes': 'Dibujo del rostro' } solo tomalo como ejemplo"

prepared_prompt = f"Contexto:{data}\n {prompt}"
print(prepared_prompt)
# Out:
# Contexto:[{'Entidades': ['Cantidad de personas', 'Edades', 'Interes'], 'Relaciones': ['75 personas', '7 a 65 años', 'Dibujo de paisajes']}, {'Entidades': ['Cantidad de personas', 'Edades', 'Interes'], 'Relaciones': ['96 personas', '15 a 45 años', 'Dibujo del rostro']}, {'Entidades': ['Cantidad de personas', 'Edades', 'Interes'], 'Relaciones': ['200 personas', '10 a 35 años', 'Dibujo de la figura humana']}, {'Entidades': ['Cantidad de personas', 'Edades', 'Interes'], 'Relaciones': ['80 personas', '12 a 35 años', 'Dibujo de animales']}, {'Entidades': ['Cantidad de personas', 'Edades', 'Interes'], 'Relaciones': ['20 personas', '45 a 60 años', 'Dibujo de bodegón']}]
#  Quiero que tomando en cuenta los datos del contexto extraigas entidades y relaciones entre los datos con el objetivo de crear un gráfico {'Cantidad': '75 personas', 'Rango etario': '7 a 65 años', 'Interes': 'Dibujo de paisajes'}, {'Cantidad': '96 personas', 'Rango etario': '10 a 35 años' 'Interes': 'Dibujo del rostro' } solo tomalo como ejemplo

# %%
# Make the request
conversation = [
        {"role": "system", "content": "Eres un asistente util, tu objetivo principal es extraer todas las relaciones entre las entidades y sus datos,  retorna un array de objetos"},
        {"role": "user", "content": prepared_prompt},
    ]

# Make the request
response = openai.ChatCompletion.create(
    model= 'gpt-3.5-turbo',
    max_tokens=800,
    messages=conversation
    )

message = response.choices[0]['message']
print("{}: {}".format(message['role'], message['content']))
# Out:
# assistant: [
#     {'Cantidad': '75 personas', 'Rango etario': '7 a 65 años', 'Interes': 'Dibujo de paisajes'},
#     {'Cantidad': '96 personas', 'Rango etario': '15 a 45 años', 'Interes': 'Dibujo del rostro'},
#     {'Cantidad': '200 personas', 'Rango etario': '10 a 35 años', 'Interes': 'Dibujo de la figura humana'},
#     {'Cantidad': '80 personas', 'Rango etario': '12 a 35 años', 'Interes': 'Dibujo de animales'},
#     {'Cantidad': '20 personas', 'Rango etario': '45 a 60 años', 'Interes': 'Dibujo de bodegón'}
# ]

# %%
import networkx as nx

G = nx.MultiDiGraph()

data = eval(message['content'])
print(f"data {data}")
#data = eval(str(data))

for d in data:
         G.add_edge(d['Cantidad'], d['Interes'],**d)
# Out:
# data [{'Cantidad': '75 personas', 'Rango etario': '7 a 65 años', 'Interes': 'Dibujo de paisajes'}, {'Cantidad': '96 personas', 'Rango etario': '15 a 45 años', 'Interes': 'Dibujo del rostro'}, {'Cantidad': '200 personas', 'Rango etario': '10 a 35 años', 'Interes': 'Dibujo de la figura humana'}, {'Cantidad': '80 personas', 'Rango etario': '12 a 35 años', 'Interes': 'Dibujo de animales'}, {'Cantidad': '20 personas', 'Rango etario': '45 a 60 años', 'Interes': 'Dibujo de bodegón'}]

# %%
pos = nx.spring_layout(G, k=0.8)  # layout spring for the nodes position
nx.draw(G, pos, with_labels=True, node_color='pink', node_size=2000, font_size=8, edge_color='blue', width=1, alpha=0.8)

# Etiquetas de los bordes
edge_labels = {(n1, n2): data.get('Rango etario') for n1, n2, data in G.edges(data=True)}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8)
# Out:
# {('75 personas',
#   'Dibujo de paisajes'): Text(0.06480243406820192, 0.6598370078112207, '7 a 65 años'),
#  ('96 personas',
#   'Dibujo del rostro'): Text(-0.3398937872251835, -0.9804325225486628, '15 a 45 años'),
#  ('200 personas',
#   'Dibujo de la figura humana'): Text(0.2618111803137284, -0.4651315132489886, '10 a 35 años'),
#  ('80 personas',
#   'Dibujo de animales'): Text(-0.7560713930610601, 0.5970131143318245, '12 a 35 años'),
#  ('20 personas',
#   'Dibujo de bodegón'): Text(0.7693515659043133, 0.18871391365460616, '45 a 60 años')}
